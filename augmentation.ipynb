# %%
import math,time,os
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
def parse_label(path):
    raw = open(path).read()
    classnames =[]
    for cls in raw.split('\n'):
        if cls == '':
            continue
        classnames.append(cls)
    return classnames
train_dir = 'data/train/'
class_names = parse_label(train_dir+'classes_label.txt')
train_file_dirs = [train_dir+classname for classname in class_names]

# %%
for i,file_dir in enumerate(train_file_dirs):
    filenames =  [file_dir+'/'+filename for filename in os.listdir(file_dir)]
    num = len(filenames)
    if num > 1500 :
        continue
    elif num > 1000:
        for filename in filenames:
            image_raw_data = tf.io.read_file(filename)
            image_decoded = tf.image.decode_jpeg(image_raw_data,3)
            image_aug = tf.image.random_flip_left_right(tf.image.random_flip_up_down(image_decoded))
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/flip-'+filename.split('/')[-1],encoded_image)
    elif num > 700:
        for filename in filenames:
            image_raw_data = tf.io.read_file(filename)
            image_decoded = tf.image.decode_jpeg(image_raw_data,3)
            image_aug = tf.image.random_flip_left_right(tf.image.random_flip_up_down(image_decoded))
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/flip-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_contrast(image_decoded,0.2,0.5)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/ctra-'+filename.split('/')[-1],encoded_image)
    elif num > 500:
        for filename in filenames:
            image_raw_data = tf.io.read_file(filename)
            image_decoded = tf.image.decode_jpeg(image_raw_data,3)
            image_aug = tf.image.random_flip_left_right(tf.image.random_flip_up_down(image_decoded))
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/flip-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_contrast(image_decoded,0.2,0.5)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/ctra-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_brightness(image_decoded,0.5)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/bri-'+filename.split('/')[-1],encoded_image)
    elif num > 300:
        for filename in filenames:
            image_raw_data = tf.io.read_file(filename)
            image_decoded = tf.image.decode_jpeg(image_raw_data,3)
            image_aug = tf.image.random_flip_up_down(image_decoded)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/ud-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_flip_left_right(image_decoded)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/lr-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_contrast(image_decoded,0.2,0.5)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/ctra-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_brightness(image_decoded,0.5)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/bri-'+filename.split('/')[-1],encoded_image)
    else:
        for filename in filenames:
            image_raw_data = tf.io.read_file(filename)
            image_decoded = tf.image.decode_jpeg(image_raw_data,3)
            image_aug = tf.image.random_flip_up_down(image_decoded)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/ud-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_flip_left_right(image_decoded)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/lr-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_contrast(image_decoded,0.2,0.5)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/ctra-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_brightness(image_decoded,0.5)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/bri-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_contrast(image_aug,0.2,0.5)
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/brct-'+filename.split('/')[-1],encoded_image)
            [w,h,c] = image_decoded.shape
            image_aug = tf.image.random_crop(image_decoded,[int(w*0.7),int(h*0.7),3])
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/crop-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_flip_up_down(tf.image.random_crop(image_decoded,[int(w*0.7),int(h*0.7),3]))
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/crud-'+filename.split('/')[-1],encoded_image)
            image_aug = tf.image.random_flip_left_right(tf.image.random_crop(image_decoded,[int(w*0.7),int(h*0.7),3]))
            encoded_image = tf.io.encode_jpeg(image_aug)
            tf.io.write_file(file_dir+'/crlr-'+filename.split('/')[-1],encoded_image)
    print(file_dir)
# Out:
# data/train/玻璃
# data/train/口服液瓶
# data/train/口罩
# data/train/牙刷
# data/train/尿布
# data/train/塑料瓶
# data/train/报纸
# data/train/易拉罐
# data/train/纸箱
# data/train/果蔬
# data/train/电池
# data/train/打火机
# data/train/废弃灯泡
# data/train/花盆
# data/train/卫生纸
# data/train/纱布
# data/train/棉签
# data/train/橡胶手套
# data/train/化妆刷
# data/train/创口贴
# data/train/一次性筷子
# data/train/熟食
# data/train/塑料袋
# data/train/手机
# data/train/笔
# data/train/笔记本
# data/train/背包
# data/train/键盘
# data/train/电子表
# data/train/电脑
# data/train/鼠标
# data/train/杯子
# data/train/磁带
# data/train/帽子
# data/train/电子闹钟
# data/train/皮带
# data/train/袜子
# data/train/刀

# %%
def _decode_and_resize(filename, label):
    image_string = tf.io.read_file(filename)  # 读取原始文件
    image_decoded = tf.io.decode_jpeg(image_string,channels=3)  # 解码JPEG图片
    image_resized = tf.image.resize(image_decoded, [224, 224]) / 255.0
    return image_resized, label

def load_data(dirs):
    images_name = []
    labels = []
    for i,file_dir in enumerate(dirs):
        filename = tf.constant([file_dir + '/' + filename for filename in os.listdir(file_dir)])
        print(filename)
        images_name = tf.concat([images_name,filename],axis=-1)
        labels = tf.concat([labels,tf.constant(i,shape=filename.shape[0])],axis=-1)
    print("total:%d" %  images_name.shape[0])
    train_dataset = tf.data.Dataset.from_tensor_slices((images_name, labels))
    train_dataset = train_dataset.map(
        map_func=_decode_and_resize,
        num_parallel_calls=tf.data.experimental.AUTOTUNE)
    return train_dataset

# %%
train_dataset = load_data([train_dir+'一次性筷子'])
train_dataset = train_dataset.batch(1)
for bn,(images,labels) in enumerate(train_dataset):
    print(bn)
    continue

# %%
for train_file_dir in train_file_dirs:
    print(train_file_dir)
    train_dataset = load_data([train_file_dir])
    train_dataset = train_dataset.batch(1)
    for bn,(images,labels) in enumerate(train_dataset):
#         print(bn)
        continue

# %%
image_raw_data = tf.io.read_file('./data/train/打火机/117.png')
image_decode = tf.image.decode_png(image_raw_data)

# %%
image_raw_data = tf.io.read_file('data/train/果蔬/biological1.jpg')
image_decoded = tf.image.decode_jpeg(image_raw_data,3)
[w,h,c] = image_decoded.shape
image_aug = tf.image.random_crop(image_decoded,[int(w*0.7),int(h*0.7),3])
plt.imshow(image_aug.numpy())

# %%
def parse_label(path):
    raw = open(path).read()
    classnames =[]
    for cls in raw.split('\n'):
        if cls == '':
            continue
        classnames.append(cls)
    return classnames

def _decode_and_resize(filename, label):
    image_string = tf.io.read_file(filename)  # 读取原始文件
    image_decoded = tf.io.decode_jpeg(image_string,channels=3)  # 解码JPEG图片
    image_resized = tf.image.resize(image_decoded, [224, 224]) / 255.0
    return image_resized, label

def load_data(dirs):
    images_name = []
    labels = []
    for i,file_dir in enumerate(dirs):
        filename = tf.constant([file_dir + '/' + filename for filename in os.listdir(file_dir)])
        images_name = tf.concat([images_name,filename],axis=-1)
        labels = tf.concat([labels,tf.constant(i,shape=filename.shape[0])],axis=-1)
    print("total:%d" %  images_name.shape[0])
    train_dataset = tf.data.Dataset.from_tensor_slices((images_name, labels))
    train_dataset = train_dataset.map(
        map_func=_decode_and_resize,
        num_parallel_calls=tf.data.experimental.AUTOTUNE)
    return train_dataset
#设置超参数
num_epochs = 10
batch_size_dense = 15
batch_size_mobile = 30
learning_rate_dense = 0.1
learning_rate_mobile = 0.02
buffer_size=12000

train_dir = './data/train/'
class_names = parse_label(train_dir+'classes_label.txt')
train_file_dirs = [train_dir+classname for classname in class_names] 
train_dataset = load_data(train_file_dirs)
train_dataset = train_dataset.shuffle(buffer_size)
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# total:94175
